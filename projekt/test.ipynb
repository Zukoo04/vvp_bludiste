# %%
from Maze import Maze

# %%
maze_instance = Maze(filename="maze_1.csv")
path = maze_instance.dijkstra_shortest_path()
maze_instance.draw_maze_with_path()

# %%
maze_instance = Maze(filename="maze_2.csv")
path = maze_instance.dijkstra_shortest_path()
maze_instance.draw_maze_with_path()

# %%
maze_instance = Maze(filename="maze_3.csv")
path = maze_instance.dijkstra_shortest_path()
maze_instance.draw_maze_with_path()

# %%
maze_instance = Maze(filename="maze_4.csv")
path = maze_instance.dijkstra_shortest_path()
maze_instance.draw_maze_with_path()

# %%
maze_instance = Maze(filename="maze_5.csv")
path = maze_instance.dijkstra_shortest_path()
maze_instance.draw_maze_with_path()

# %%
maze_instance = Maze(size=30, template="slalom")
path = maze_instance.dijkstra_shortest_path()
maze_instance.draw_maze_with_path()

# %%
maze = Maze(size=20, template="random", barrier_density=0.5)
maze.dijkstra_shortest_path()
maze.draw_maze_with_path()
